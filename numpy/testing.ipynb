# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np

print("Numpy version:", np.__version__)
# Out:
# Numpy version: 2.5.0

# %%
numbers = np.array([10,20,30,40,50])

print("Array: ", numbers)
print("Mean: ", numbers.mean)
print("Sum: ", numbers.sum)
# Out:
# Array:  [10 20 30 40 50]
# Mean:  <built-in method mean of numpy.ndarray object at 0x0000024081836250>
# Sum:  <built-in method sum of numpy.ndarray object at 0x0000024081836250>
